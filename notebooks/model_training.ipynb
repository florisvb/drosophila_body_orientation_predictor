# %% [markdown]
# # [drosophila_body_orientation_predictor](https://github.com/nehalsinghmangat/drosophila_body_orientation_predictor) — Neural Network Training
#
# This notebook trains and evaluates the neural network for predicting *Drosophila* body heading angle. It loads the preprocessed trajectory data produced by the data pipeline notebook (`data_pipeline.ipynb`) from `../pipelinedata/06_final/`, constructs time-delay–embedded features, performs a hyperparameter grid search, saves the best model to `../models/model.keras`, and visualises predictions on both the training dataset (Floris et al.) and an external dataset (David's data).

# %% [markdown]
# #### Pull Out Individual Trajectories
#
# Split the concatenated DataFrame into a list of per-trajectory DataFrames, discarding trajectories below the minimum length threshold.

# %%
import os
import sys
import pandas as pd
import numpy as np

sys.path.insert(0, os.path.abspath('../utils'))

from utils import pull_out_individual_trajectories

final_fly_data = pd.read_csv("../pipelinedata/06_final/all_wind_heading_and_trajectories_augmented_corrected_filtered_headx_heady.csv")
fly_traj_list = pull_out_individual_trajectories(final_fly_data, min_traj_length=12)
# Out:
# Detected 2386 trajectories.
# 2340 trajectories with more than 12 timesteps.

# %% [markdown]
# #### Construct Delay-Embedded Feature Matrix
#
# Apply time-delay embedding to each trajectory independently, then concatenate across trajectories to form the final feature matrix. Input names and window size are defined here and reused during inference.

# %%
from utils import augment_with_time_delay_embedding

time_window = 4

input_names = [
    'groundspeed',
    'groundspeed_angle',
    'airspeed',
    'airspeed_angle',
    'thrust',
    'thrust_angle',
]

output_names = ['heading_angle_x', 'heading_angle_y']

n_input = len(input_names) * time_window
n_output = len(output_names)

print('Inputs:', n_input)
print('Output:', n_output)

time_augmentation_kwargs = {
    "time_window": time_window,
    "input_names": input_names,
    "output_names": output_names,
    "direction": "backward"
}

# Original unaugmented data (real wind-tunnel distribution)
traj_augment_original = augment_with_time_delay_embedding(fly_traj_list, **time_augmentation_kwargs)

# Wind-augmented + wrapped data (simulates all wind directions)
traj_augment_wind = augment_with_time_delay_embedding(fly_traj_list, wind_augment=True, wrap_angles=True, **time_augmentation_kwargs)

# Combined dataset: original + augmented
traj_augment_all = pd.concat([traj_augment_original, traj_augment_wind], ignore_index=True)

print(f'Original samples:  {len(traj_augment_original):,}')
print(f'Augmented samples: {len(traj_augment_wind):,}')
print(f'Combined samples:  {len(traj_augment_all):,}')

os.makedirs('../pipelinedata/07_time_delay_embedded', exist_ok=True)
traj_augment_original.to_csv('../pipelinedata/07_time_delay_embedded/traj_augment_original.csv', index=False)

os.makedirs('../pipelinedata/08_wind_augmented', exist_ok=True)
traj_augment_all.to_csv('../pipelinedata/08_wind_augmented/traj_augment_wind_plus_original.csv', index=False)
# Out:
# Inputs: 24
# Output: 2
# Original samples:  64,026
# Augmented samples: 64,026
# Combined samples:  128,052

# %% [markdown]
# ### Neural Network Training
#
# The network is a fully-connected feedforward architecture with $L$ hidden layers of $N$ ReLU neurons each, followed by a 2-dimensional linear output layer predicting $(\cos\theta, \sin\theta)$. We use a grid search over $L \in \{1,2,3\}$ and $N \in \{10,15,20\}$ with 3-fold cross-validation to select hyperparameters.
#
# #### Train/Test Split

# %%
from sklearn.model_selection import train_test_split
# Input data
X = traj_augment_all.iloc[:, 0:n_input]
# Output data
y = traj_augment_all.iloc[:, n_input:]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# #### Hyperparameter Search and Model Fitting
#
# Grid search over network depth and width using `GridSearchCV` with `scikeras`. Each candidate is trained for 150 epochs (batch size 256, 20% validation split). The best configuration is saved to `model.keras`.

# %%
import os
import keras
from keras.models import Sequential
from keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from functools import partial
from sklearn.model_selection import GridSearchCV

from utils import create_model

model_with_inputs_and_outputs = partial(create_model, n_input=n_input, n_output=n_output)
clf = KerasRegressor(model=model_with_inputs_and_outputs, epochs=150, batch_size=256,
                     validation_split=0.2, layers=1, neurons=20, verbose=0)

param_grid = {
    'neurons': [10, 15, 20],
    'layers': [1, 2, 3],
}

grid = GridSearchCV(estimator=clf, param_grid=param_grid,
                    scoring='neg_mean_squared_error', n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, y_train)

df_results = pd.DataFrame(grid_result.cv_results_)
print(df_results[['param_layers', 'param_neurons', 'mean_test_score', 'std_test_score', 'rank_test_score']])

best_estimator = grid.best_estimator_
os.makedirs('../models', exist_ok=True)
best_estimator.model_.save('../models/drosophila_body_orientation_predictor.keras')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868588.567797   46093 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868588.568442   46093 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868588.593094   46093 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868589.598841   46093 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868589.599209   46093 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.783806   46145 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.783926   46144 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.783987   46157 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.783983   46148 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.784288   46145 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868591.784307   46144 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868591.784374   46157 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868591.784386   46148 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.838703   46150 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.839417   46150 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.844319   46146 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.845061   46146 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.860533   46147 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.861177   46147 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868591.862221   46144 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1781868591.862222   46157 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1781868591.862221   46145 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1781868591.862221   46148 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.869140   46153 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.869866   46153 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.877836   46154 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.878449   46154 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.905193   46151 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.905894   46151 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868591.919316   46150 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.922010   46152 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.922669   46152 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868591.927549   46146 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.938944   46155 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.939656   46155 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868591.944406   46147 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.949080   46156 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.949742   46156 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868591.956640   46153 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1781868591.957126   46154 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.962733   46158 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.963421   46158 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868591.982303   46149 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868591.982970   46149 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868591.991014   46151 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1781868592.012994   46152 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1781868592.025238   46155 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1781868592.033997   46156 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1781868592.048523   46158 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1781868592.067958   46149 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868592.087353   46159 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868592.088013   46159 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781868592.175732   46159 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.443460   46145 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.444505   46145 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.458705   46144 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.459753   46144 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.462197   46148 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.463157   46148 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.479140   46157 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.480191   46157 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.490072   46146 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.491141   46146 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.499386   46154 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.500398   46154 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.514131   46150 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.515161   46150 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.520191   46153 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.521210   46153 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.556183   46147 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.557222   46147 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.569409   46151 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.570453   46151 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.607003   46156 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.608081   46156 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.619386   46152 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.620459   46152 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.623764   46155 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.624786   46155 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.646020   46149 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.647245   46149 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.647688   46158 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.648655   46158 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781868594.859658   46159 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781868594.860811   46159 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.686390   46148 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.706436   46145 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.729184   46144 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.738150   46146 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# E0000 00:00:1781868597.739470   46150 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# E0000 00:00:1781868597.739770   46157 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.768127   46153 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.791446   46154 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.815467   46147 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.826463   46151 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.847409   46156 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.870449   46152 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.938958   46155 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868597.943856   46158 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# E0000 00:00:1781868597.949168   46149 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868598.137954   46159 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1781868851.351284   46093 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
#    param_layers  param_neurons  mean_test_score  std_test_score  \
# 0             1             10        -0.061143        0.000898
# 1             1             15        -0.057022        0.001079
# 2             1             20        -0.054285        0.000744
# 3             2             10        -0.053785        0.001121
# 4             2             15        -0.050737        0.000712
# 5             2             20        -0.047733        0.000424
# 6             3             10        -0.052078        0.000770
# 7             3             15        -0.048207        0.001737
# 8             3             20        -0.046092        0.001115
#
#    rank_test_score
# 0                9
# 1                8
# 2                7
# 3                6
# 4                4
# 5                2
# 6                5
# 7                3
# 8                1

# %% [markdown]
# ### Prediction Wrapper and Post-Processing
#
# During inference, the same feature-construction pipeline used during training is applied to a new trajectory. The trained network produces a sequence of 2D outputs $(\hat{x}_t, \hat{y}_t)$ on the unit circle, converted to heading angle via $\hat{\theta}_t = \text{arctan2}(\hat{y}_t, \hat{x}_t)$.
#
# An optional Gaussian smoothing filter ($\sigma = 2$) suppresses frame-to-frame jitter in the predicted components before angle recovery. Because the delay embedding requires $W-1$ prior observations, the first $W-1$ predictions are filled by repeating the first predicted value, yielding a time-aligned output of the same length as the input trajectory.
#
# See `utils.plot_trajectory_with_predicted_heading` for the full implementation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import fly_plot_lib_plot as fpl
#import figurefirst as fifi
import pandas as pd
import matplotlib
import matplotlib.colors as mcolors
from keras.models import load_model

from utils import (
    plot_trajectory_with_predicted_heading,
    augment_with_time_delay_embedding,
    blue_cmap,
    red_cmap,
)

best_estimator = load_model('../models/drosophila_body_orientation_predictor.keras', safe_mode=False)

# %% [markdown]
# ## Results
#
# ### Neural Network Performance on the Training Dataset (Floris et al.)
#
# We visualize model predictions overlaid on true headings for a random sample of trajectories, and plot 2D density histograms of predicted vs. true heading angles for training and test sets.

# %% [markdown]
# #### Load Preprocessed Training Data

# %%
final_fly_data = pd.read_csv('../pipelinedata/06_final/all_wind_heading_and_trajectories_augmented_corrected_filtered_headx_heady.csv')
body_and_trajectory_by_id = [group for _, group in final_fly_data.groupby('trajec_objid')]

# %% [markdown]
# #### Trajectory Plots: Predicted vs. True Heading

# %%
import random
import gc

sampled_trajectories = random.sample(body_and_trajectory_by_id, 10)
# Loop through each trajectory and create/save figures
for trajectory in sampled_trajectories:
    trajec_objid = trajectory["trajec_objid"].iloc[0]
    fig, ax = plt.subplots(figsize=(12, 12), dpi=150)
    plot_trajectory_with_predicted_heading(trajectory, ax, n_input, best_estimator, include_id=True, nskip=4, smooth=True, **time_augmentation_kwargs)

    os.makedirs('../pipelinedata/06_final/predicted_heading_svgs', exist_ok=True)
    svg_filename = f'../pipelinedata/06_final/predicted_heading_svgs/{trajec_objid}.svg'
    plt.savefig(svg_filename, format='svg')
    plt.close(fig)
    gc.collect()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# ##### Figure 2 Panel C

# %%
from sklearn.model_selection import train_test_split

# Combined dataset (training distribution)
X = traj_augment_all.iloc[:, 0:n_input]
y = traj_augment_all.iloc[:, n_input:]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Unaugmented only (to evaluate on the real inference distribution)
X_unaug = traj_augment_original.iloc[:, 0:n_input]
y_unaug = traj_augment_original.iloc[:, n_input:]
X_train_unaug, X_test_unaug, y_train_unaug, y_test_unaug = train_test_split(X_unaug, y_unaug, test_size=0.33, random_state=42)

# Wind-augmented + wrapped only
X_wind = traj_augment_wind.iloc[:, 0:n_input]
y_wind = traj_augment_wind.iloc[:, n_input:]
X_train_wind, X_test_wind, y_train_wind, y_test_wind = train_test_split(X_wind, y_wind, test_size=0.33, random_state=42)

# %%
import os, sys
import matplotlib.pyplot as plt
sys.path.insert(0, os.path.abspath('../utils'))
import pandas as pd
from keras.models import load_model
from utils import custom_density_plots, make_color_map

time_window  = 4
input_names  = ['groundspeed', 'groundspeed_angle', 'airspeed', 'airspeed_angle', 'thrust', 'thrust_angle']
output_names = ['heading_angle_x', 'heading_angle_y']
n_input = len(input_names) * time_window

best_estimator = load_model('../models/drosophila_body_orientation_predictor.keras', safe_mode=False)

traj_augment_original = pd.read_csv('../pipelinedata/07_time_delay_embedded/traj_augment_original.csv')
traj_augment_all      = pd.read_csv('../pipelinedata/08_wind_augmented/traj_augment_wind_plus_original.csv')
traj_augment_wind     = traj_augment_all.iloc[len(traj_augment_original):].reset_index(drop=True)

X_base = traj_augment_original.iloc[:, 0:n_input]
y_base = traj_augment_original.iloc[:, n_input:]

X_wind = traj_augment_wind.iloc[:, 0:n_input]
y_wind = traj_augment_wind.iloc[:, n_input:]

cmap = make_color_map(color_list=['white', 'navy', 'cornflowerblue', 'aqua', 'yellow', 'red', 'darkred'], N=256)

fig, axs = plt.subplots(1, 2, figsize=(9, 4.5), dpi=150)

custom_density_plots([axs[0], axs[1]], [X_base, X_wind], [y_base, y_wind],
                     best_estimator, cmap, titles=["Base Dataset", "Rotation-Augmented Dataset"])

fig.tight_layout()
os.makedirs('../figures', exist_ok=True)
fig.savefig('../figures/fig_2_panel_C.svg', format='svg', bbox_inches='tight')
plt.show()
# Out:
#  1/16 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#  1/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ### Prediction on External Data (David's Dataset)
#
# We apply the trained estimator to an independent trajectory dataset (David's data) in which only center-of-mass motion was recorded — no body orientation measurements exist. This demonstrates the estimator's utility for recovering heading information from trajectory-only data.

# %% [markdown]
# #### Augment David's Data
#
# David's dataset uses different field names and lacks the ellipse-based heading. We rename fields, add the necessary wind/airspeed columns, and run `augment_fly_trajectory` with `compute_heading_from_ellipses=False` to compute the kinematic features without overwriting the provided heading angle.

# %%
from utils import augment_fly_trajectory

# %%
import os
import numpy as np

from utils import augment_fly_trajectory

orco_laminar_files = [
    '../experimentaldata/external/orco_laminar1.csv',
    '../experimentaldata/external/orco_traj2.csv',
    '../experimentaldata/external/orco_traj3.csv',
]

all_dfs = []
for fpath in orco_laminar_files:
    temp = pd.read_csv(fpath)
    temp.rename(columns={
        'obj_id_unique': 'trajec_objid', 'x': 'position_x', 'y': 'position_y',
        'heading': 'heading_angle', 'xvel': 'velocity_x', 'yvel': 'velocity_y',
    }, inplace=True)
    temp = temp[["trajec_objid", "timestamp", "position_x", "position_y",
                  "velocity_x", "velocity_y", "heading_angle"]]
    temp['windspeed'] = 0.4
    temp['windspeed_angle'] = -np.pi
    temp['airvelocity_x'] = temp['velocity_x'] + 0.4
    temp['airvelocity_y'] = temp['velocity_y']
    temp['heading_angle_x'] = np.cos(temp['heading_angle'])
    temp['heading_angle_y'] = np.sin(temp['heading_angle'])
    all_dfs.append(temp)

temp_fly_data = pd.concat(all_dfs, ignore_index=True)
temp_fly_data = [group for _, group in temp_fly_data.groupby('trajec_objid')]
temp_fly_data = [t for t in temp_fly_data if len(t) > 12]
temp_fly_data = [augment_fly_trajectory(t, compute_heading_from_ellipses=False) for t in temp_fly_data]

David_fly_data = pd.concat(temp_fly_data, ignore_index=True)
os.makedirs('../pipelinedata/external', exist_ok=True)
David_fly_data.to_csv('../pipelinedata/external/david_data_augmented.csv')
# Out:
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/pynumdiff/polynomial_fit.py:149: UserWarning: Kernel window size should be odd. Added 1 to length.
#   warn("Kernel window size should be odd. Added 1 to length.")
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/pynumdiff/polynomial_fit.py:149: UserWarning: Kernel window size should be odd. Added 1 to length.
#   warn("Kernel window size should be odd. Added 1 to length.")
# /home/nehal/projectile/test/drosophila_body_orientation_predictor/.venv/lib/python3.12/site-packages/pynumdiff/polynomial_fit.py:149: UserWarning: Kernel window size should be odd. Added 1 to length.
#   warn("Kernel window size should be odd. Added 1 to length.")

# %% [markdown]
# #### Load Augmented External Data

# %%
David_fly_data = pd.read_csv('../pipelinedata/external/david_data_augmented.csv')
body_and_trajectory_by_id = [group for _, group in David_fly_data.groupby('trajec_objid')]

# %% [markdown]
# #### Apply Prediction Wrapper
#
# `plot_trajectory_with_predicted_heading` (imported from `utils`) applies the delay-embedding pipeline and runs inference, then overlays the predicted heading (blue) and true heading (red) on the trajectory plot.

# %% [markdown]
# #### Trajectory Plots: Predictions on External Data

# %%
import random


# Loop through each trajectory and create/save figures
for trajectory in body_and_trajectory_by_id:
    trajec_objid = trajectory["trajec_objid"].iloc[0]
    fig, ax = plt.subplots(figsize=(12, 12), dpi=150)
    plot_trajectory_with_predicted_heading(trajectory, ax, n_input, best_estimator, include_id=True, nskip=4, smooth=True, **time_augmentation_kwargs)

    os.makedirs('../figures/external_data_predicted_heading', exist_ok=True)
    svg_filename = f'../figures/external_data_predicted_heading/{trajec_objid}.svg'
    plt.savefig(svg_filename, format='svg')
    plt.close(fig)
    gc.collect()
# Out:
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#  1/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#  1/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ##### Figure 2 Panel B

# %%
import os, sys
import matplotlib.pyplot as plt
sys.path.insert(0, os.path.abspath('../utils'))
import pandas as pd
from keras.models import load_model
from utils import plot_trajectory_with_predicted_heading

time_window  = 4
input_names  = ['groundspeed', 'groundspeed_angle', 'airspeed', 'airspeed_angle', 'thrust', 'thrust_angle']
output_names = ['heading_angle_x', 'heading_angle_y']
n_input = len(input_names) * time_window
time_augmentation_kwargs = {
    "time_window": time_window, "input_names": input_names,
    "output_names": output_names, "direction": "backward",
}

best_estimator = load_model('../models/drosophila_body_orientation_predictor.keras', safe_mode=False)

David_fly_data    = pd.read_csv('../pipelinedata/external/david_data_augmented.csv')
test_trajec_David = David_fly_data.loc[David_fly_data["trajec_objid"] == "2770_20220927_170437"]

fig, ax = plt.subplots(figsize=(12, 12), dpi=150)
plot_trajectory_with_predicted_heading(test_trajec_David[250:400], ax, n_input, best_estimator,
    include_id=True, nskip=8, smooth=True, **time_augmentation_kwargs)

os.makedirs('../figures', exist_ok=True)
fig.savefig('../figures/fig_2_panel_B.svg', format='svg', bbox_inches='tight')
plt.show()
# Out:
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
